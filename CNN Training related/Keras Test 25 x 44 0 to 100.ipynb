# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from os import listdir
from os.path import isfile, join
from sklearn.utils import shuffle
import cv2
import numpy as np

batch_size = 100
num_classes = 100
epochs = 8

# input image dimensions
#img_rows, img_cols = 28, 28
img_rows, img_cols = 25, 44

# the data, split between train and test sets
#(x_train, y_train), (x_test, y_test) = mnist.load_data()

#if K.image_data_format() == 'channels_first':
#    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
#    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
#    input_shape = (1, img_rows, img_cols)
#else:
#    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
#    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
#    input_shape = (img_rows, img_cols, 1)

#x_train = x_train.astype('float32')
#x_test = x_test.astype('float32')
#x_train /= 255
#x_test /= 255


 
rpath = "F:/Google Drive/User_Backup/training"
#wpath = "F:/Google Drive/User_Backup/training"
h_max, w_max, h_out, w_out = 75, 132, 25, 44
image = []
answer = []
for j in range (0, 100):
#   print(j)
    for k in range (5000):
        tpath = rpath + "/" + str(j) + "/" + str(k) + ".png"
        img = cv2.imread(tpath, 0)
        image.append(img)
        answer.append(j)

print(len(image))
print(len(answer))
train_image, answer = shuffle(image, answer)
i = 0

x_train = np.array(train_image[:449999])
x_test = np.array(train_image[450000:499999])
y_train = np.array(answer[:449999])
y_test = np.array(answer[450000:499999])
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
from keras.models import load_model
model.save("F:/Google Drive/User_Backup/model/trained.h5")
# Out:
# 500000
# 500000
# x_train shape: (449999, 25, 44, 1)
# 449999 train samples
# 49999 test samples
# Train on 449999 samples, validate on 49999 samples
# Epoch 1/30
# 449999/449999 [==============================] - 2114s 5ms/step - loss: 1.0780 - accuracy: 0.7108 - val_loss: 0.2764 - val_accuracy: 0.9177
# Epoch 2/30
# 449999/449999 [==============================] - 1992s 4ms/step - loss: 0.3098 - accuracy: 0.9103 - val_loss: 0.1455 - val_accuracy: 0.9570
# Epoch 3/30
# 449999/449999 [==============================] - 2056s 5ms/step - loss: 0.2106 - accuracy: 0.9385 - val_loss: 0.1024 - val_accuracy: 0.9711
# Epoch 4/30
# 449999/449999 [==============================] - 2113s 5ms/step - loss: 0.1664 - accuracy: 0.9519 - val_loss: 0.0873 - val_accuracy: 0.9751
# Epoch 5/30
# 449999/449999 [==============================] - 2214s 5ms/step - loss: 0.1399 - accuracy: 0.9594 - val_loss: 0.0723 - val_accuracy: 0.9796
# Epoch 6/30
# 449999/449999 [==============================] - 2212s 5ms/step - loss: 0.1242 - accuracy: 0.9639 - val_loss: 0.0679 - val_accuracy: 0.9818
# Epoch 7/30
# 449999/449999 [==============================] - 2385s 5ms/step - loss: 0.1136 - accuracy: 0.9674 - val_loss: 0.0662 - val_accuracy: 0.9823
# Epoch 8/30
# 449999/449999 [==============================] - 2240s 5ms/step - loss: 0.1058 - accuracy: 0.9696 - val_loss: 0.0583 - val_accuracy: 0.9848
# Epoch 9/30
# 449999/449999 [==============================] - 2319s 5ms/step - loss: 0.1011 - accuracy: 0.9712 - val_loss: 0.0710 - val_accuracy: 0.9827
# Epoch 10/30
#   3100/449999 [..............................] - ETA: 37:20 - loss: 0.0934 - accuracy: 0.9706
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-7afa777aae6c> in <module>
#      98           epochs=epochs,
#      99           verbose=1,
# --> 100           validation_data=(x_test, y_test))
#     101 score = model.evaluate(x_test, y_test, verbose=0)
#     102 print('Test loss:', score[0])
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3738         value = math_ops.cast(value, tensor.dtype)
#    3739       converted_inputs.append(value)
# -> 3740     outputs = self._graph_fn(*converted_inputs)
#    3741
#    3742     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1079       TypeError: For invalid positional/keyword argument combinations.
#    1080     """
# -> 1081     return self._call_impl(args, kwargs)
#    1082
#    1083   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1119       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1120           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1121     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1122
#    1123   def _filtered_call(self, args, kwargs):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.models import load_model
from os import listdir
from os.path import isfile, join
from sklearn.utils import shuffle
import cv2
import numpy as np

batch_size = 100
num_classes = 100
epochs = 8

img_rows, img_cols = 25, 44

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

model = "F:/Google Drive/User_Backup/model/"
#model.save("F:/Google Drive/User_Backup/model/trained.h5")
json_string = model.to_json()
open(os.path.join(model,'cnn_model2.json'), 'w').write(json_string)
yaml_string = model.to_yaml()
open(os.path.join(model,'cnn_model2.yaml'), 'w').write(yaml_string)
print('save weights')
model.save_weights(os.path.join(model,'cnn_model_weights2.hdf5'))
# Out:
# Train on 449999 samples, validate on 49999 samples
# Epoch 1/8
# 449999/449999 [==============================] - 2279s 5ms/step - loss: 1.0186 - accuracy: 0.7251 - val_loss: 0.2441 - val_accuracy: 0.9288
# Epoch 2/8
# 449999/449999 [==============================] - 2168s 5ms/step - loss: 0.3118 - accuracy: 0.9102 - val_loss: 0.1444 - val_accuracy: 0.9579
# Epoch 3/8
# 449999/449999 [==============================] - 2057s 5ms/step - loss: 0.2189 - accuracy: 0.9369 - val_loss: 0.1757 - val_accuracy: 0.9585
# Epoch 4/8
# 449999/449999 [==============================] - 2085s 5ms/step - loss: 0.1751 - accuracy: 0.9491 - val_loss: 0.0986 - val_accuracy: 0.9728
# Epoch 5/8
# 449999/449999 [==============================] - 2150s 5ms/step - loss: 0.1498 - accuracy: 0.9567 - val_loss: 0.0834 - val_accuracy: 0.9763
# Epoch 6/8
# 449999/449999 [==============================] - 6635s 15ms/step - loss: 0.1223 - accuracy: 0.9651 - val_loss: 0.0714 - val_accuracy: 0.9799
# Epoch 8/8
# 449999/449999 [==============================] - 20522s 46ms/step - loss: 0.1133 - accuracy: 0.9678 - val_loss: 0.0682 - val_accuracy: 0.9818
# Test loss: 0.0681757553146405
# Test accuracy: 0.9817596077919006
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-dc9070434f9f> in <module>
#      46
#      47 model = "F:/Google Drive/User_Backup/model/"
# ---> 48 model.save("F:/Google Drive/User_Backup/model/trained.h5")
#      49 json_string = model.to_json()
#      50 open(os.path.join(model,'cnn_model2.json'), 'w').write(json_string)
#
# AttributeError: 'str' object has no attribute 'save'

# %%
import numpy as np
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image

model = Sequential()
model.summary()
img_path = 'F:/Google Drive/User_Backup/test_data/20_1.png'
img = image.load_img(img_path, grayscale = True, target_size=(25,44))
x = image.img_to_array(img)
print('x.shape: {}, x.dtype: {}'.format(x.shape, x.dtype))
x = x.reshape(x.shape[0], 25, 44, 1)
#x = np.expand_dims(x, axis=0)
x /= 255
preds = model.predict(x)
print(preds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-9ed1abd34eff> in <module>
#       4
#       5 model = Sequential()
# ----> 6 model.summary()
#       7 img_path = 'F:/Google Drive/User_Backup/test_data/20_1.png'
#       8 img = image.load_img(img_path, grayscale = True, target_size=(25,44))
#
# ~\Anaconda3\lib\site-packages\keras\engine\network.py in summary(self, line_length, positions, print_fn)
#    1318         if not self.built:
#    1319             raise ValueError(
# -> 1320                 'This model has not yet been built. '
#    1321                 'Build the model first by calling build() '
#    1322                 'or calling fit() with some data. '
#
# ValueError: This model has not yet been built. Build the model first by calling build() or calling fit() with some data. Or specify input_shape or batch_input_shape in the first layer for automatic build.

# %%
from keras.models import load_model
model.save("F:/Google Drive/User_Backup/model/trained.h5")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-13-9b4316c16e5f> in <module>
#       1 from keras.models import load_model
# ----> 2 model.save("F:/Google Drive/User_Backup/model/trained.h5")
#
# ~\Anaconda3\lib\site-packages\keras\engine\network.py in save(self, filepath, overwrite, include_optimizer)
#    1148         """
#    1149         if not self._is_graph_network:
# -> 1150             raise NotImplementedError
#    1151         from ..models import save_model
#    1152         save_model(self, filepath, overwrite, include_optimizer)
#
# NotImplementedError:

# %%
print('x_train shape:', x_train.shape)
# Out:
# x_train shape: (449999, 25, 44, 1)

# %%
from __future__ import print_function
from keras.models import model_from_json
from keras.models import load_model
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.models import load_model
from os import listdir
from os.path import isfile, join
from sklearn.utils import shuffle
import cv2
import numpy as np

batch_size = 30
num_classes = 100
epochs = 2
img_rows, img_cols = 25, 44

npath = "F:/Google Drive/User_Backup/DataGeneration"
#wpath = "F:/Google Drive/User_Backup/training"
image = []
answer = []
#onlyfolders = [f for f in listdir(rpath)]
#for folder in onlyfolders:
    # print(rpath+"/"+folder)
#    npath = rpath +"/"+ folder
onlyfiles = [f for f in listdir(npath) if isfile(join(npath, f)) and f[-4:] == ".png"]
for file in onlyfiles:
    filename = npath + "/" + file
    img = cv2.imread(filename, 0)
 #   dim = (img_rows, img_cols)
 #       img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    image.append(img)
    p = file.find("_")
#        if not file[:p].isnumeric():
#            print(filename)
    answer.append(int(file[:p]))
print(len(image))
print(len(answer))
train_image, answer = shuffle(image, answer)
i = 0

x_train = np.array(train_image[:158597])
x_test = np.array(train_image[158598:176220])
y_train = np.array(answer[:158597])
y_test = np.array(answer[158598:176220])
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = model_from_json(open('F:/Google Drive/User_Backup/model/cnn_model.json').read())
model.load_weights('F:/Google Drive/User_Backup/model/cnn_model_weights.hdf5')

model.compile(loss=keras.losses.categorical_crossentropy,
             optimizer=keras.optimizers.Adadelta(),
             metrics=['accuracy'])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
model.save_weights('F:/Google Drive/User_Backup/model/cnn_model_weights3.hdf5')
json_string = model.to_json()
open('F:/Google Drive/User_Backup/model/cnn_model3.json', 'w').write(json_string)
yaml_string = model.to_yaml()
open('F:/Google Drive/User_Backup/model/cnn_model3.yaml', 'w').write(yaml_string)
print('save weights')
# Out:
# 176221
# 176221
# x_train shape: (158597, 25, 44, 1)
# 158597 train samples
# 17622 test samples
# Train on 158597 samples, validate on 17622 samples
# Epoch 1/2
# 158597/158597 [==============================] - 1886s 12ms/step - loss: 0.7167 - accuracy: 0.8253 - val_loss: 0.4033 - val_accuracy: 0.9043
# Epoch 2/2
# 158597/158597 [==============================] - 1835s 12ms/step - loss: 0.5024 - accuracy: 0.8736 - val_loss: 0.3285 - val_accuracy: 0.9196
# Test loss: 0.3284556039574874
# Test accuracy: 0.9195891618728638
# save weights

# %%
from __future__ import print_function
from keras.models import model_from_json
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from os import listdir
from os.path import isfile, join
from sklearn.utils import shuffle
import cv2
import numpy as np


batch_size = 30
num_classes = 100
epochs = 8
img_rows, img_cols = 25, 44

rpath = "F:/Google Drive/User_Backup/Reversed_images"
#wpath = "F:/Google Drive/User_Backup/training"
image = []
answer = []
onlyfolders = [f for f in listdir(rpath)]
for folder in onlyfolders:
    # print(rpath+"/"+folder)
    npath = rpath +"/"+ folder
    onlyfiles = [f for f in listdir(npath) if isfile(join(npath, f)) and f[-4:] == ".png"]
    for file in onlyfiles:
        filename = npath + "/" + file
        img = cv2.imread(filename, 0)
        dim = (img_rows, img_cols)
        img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
        image.append(img)
        p = file.find("_")
        if file[:p]. 
        answer.append(file[:p])
print(len(image))
print(len(answer))
train_image, answer = shuffle(image, answer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-29b4afb89abe> in <module>
#      13
#      14
# ---> 15 json_string = model.to_json()
#      16 open(os.path.join(model,'cnn_model2.json'), 'w').write(json_string)
#      17 yaml_string = model.to_yaml()
#
# AttributeError: 'str' object has no attribute 'to_json'

# %%
from os import listdir
from os.path import isfile, join
rpath = "F:/Google Drive/User_Backup/Reversed_images"
onlyfolders = [f for f in listdir(rpath)]
for folder in onlyfolders:
    # print(rpath+"/"+folder)
    npath = rpath +"/"+ folder
    onlyfiles = [f for f in listdir(npath) if isfile(join(npath, f)) and f[-4:] == ".png"]
    for file in onlyfiles:
        filename = npath + "/" + file
        p = file.find("_")
        if not file[:p].isnumeric():
            print(filename)

# %%
from __future__ import print_function
from keras.models import model_from_json
from keras.models import load_model
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.models import load_model
from os import listdir
from os.path import isfile, join
from sklearn.utils import shuffle
import cv2
import numpy as np



model_path = "F:/Google Drive/User_Backup/model/"
#model.save("F:/Google Drive/User_Backup/model/trained_add_data.h5")
#model_json = model.to_json()
#open(os.path.join(model_path,'cnn_model3.json'), 'w').write(model_json)
#yaml_string = model.to_yaml()
#open(os.path.join(model_path,'cnn_model3.yaml'), 'w').write(yaml_string)
#print('save weights')
model.save_weights('F:/Google Drive/User_Backup/model/cnn_model_weights3.hdf5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-c848e7329a00> in <module>
#      24 #open(os.path.join(model_path,'cnn_model3.yaml'), 'w').write(yaml_string)
#      25 #print('save weights')
# ---> 26 model.save_weights('F:/Google Drive/User_Backup/model/cnn_model_weights3.hdf5')
#
# AttributeError: 'str' object has no attribute 'save_weights'
